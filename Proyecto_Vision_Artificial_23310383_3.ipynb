# %% [markdown]
# <a href="https://colab.research.google.com/github/TheLuxer/Proyecto-Vision-Artificial_23310383_3/blob/main/Proyecto_Vision_Artificial_23310383_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install roboflow ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.3/41.3 kB 2.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.0/250.0 kB 14.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 7.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 21.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 74.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 95.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 131.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.13.0.92
#     Uninstalling opencv-python-headless-4.13.0.92:
#       Successfully uninstalled opencv-python-headless-4.13.0.92
#   Attempting uninstall: idna
#     Found existing installation: idna 3.18
#     Uninstalling idna-3.18:
#       Successfully uninstalled idna-3.18
# ...

# %%
from roboflow import Roboflow

rf = Roboflow(api_key="GfPp5sDs9uHUrskdwbQ6")
project = rf.workspace("prueba1-jkmge").project("cars-cars-cars")
version = project.version(2)

dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...

# %%
from ultralytics import YOLO

model = YOLO('yolov8n.pt')

results = model.train(
    data=f"{dataset.location}/data.yaml",
    epochs=25,
    imgsz=640,
    plots=True
)
# Out:
# ...
# Ultralytics 8.4.70 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
model_entrenado = YOLO('runs/detect/train/weights/best.pt')

results = model_entrenado.predict(source=f"{dataset.location}/test/images", save=True, conf=0.5)

print("Detecciones completadas. Revisa la carpeta: runs/detect/predict")
# Out:
# image 1/88 /content/cars-cars-cars-2/test/images/1001_png.rf.6408725d3e3da39bd0d8b98a69f8363f.jpg: 480x640 1 0, 1 1, 3 3s, 44.0ms
# image 2/88 /content/cars-cars-cars-2/test/images/1017_png.rf.8a587c6c43ea6369bb0ca74dd5fb0289.jpg: 480x640 1 1, 1 2, 10 3s, 9.5ms
# image 3/88 /content/cars-cars-cars-2/test/images/1025_png.rf.00753f518b6d2bb3f0f58e9b54f651e4.jpg: 480x640 1 1, 1 2, 3 3s, 6.5ms
# image 4/88 /content/cars-cars-cars-2/test/images/102_png.rf.c8ee6ea7ab327c854d3dff3cc05a0d95.jpg: 480x640 1 0, 13 3s, 5.8ms
# image 5/88 /content/cars-cars-cars-2/test/images/1036_png.rf.8c618d3e87382c57b1e23f8565702462.jpg: 480x640 2 0s, 2 2s, 13 3s, 6.4ms
# image 6/88 /content/cars-cars-cars-2/test/images/104_png.rf.186636bb620571a9ef4f016c81a65a9c.jpg: 480x640 1 0, 5 1s, 1 2, 14 3s, 6.1ms
# image 7/88 /content/cars-cars-cars-2/test/images/1052_png.rf.4ba07cd4e0f907678a706f0ef2f616fb.jpg: 480x640 1 0, 2 1s, 1 2, 28 3s, 5.9ms
# ...
